# %% [markdown]
# # Conversión de DOCX a Markdown
# Convierte todos los archivos `.docx` de `Documentos_prompts_base_docx` a `.md` en `Documentos_prompts_base_md`,
# preservando la estructura de subcarpetas (p.ej. `1.Investigación`, `2.Descubrimiento`, etc.).

# %%
# Instalar dependencias si no están disponibles
#%pip install mammoth markdownify --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script markdownify.exe is installed in 'e:\Users\1167486\AppData\Local\anaconda3\envs\data_analytics_science\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mammoth.exe is installed in 'e:\Users\1167486\AppData\Local\anaconda3\envs\data_analytics_science\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
import mammoth
from markdownify import markdownify as md
from pathlib import Path

# ── Configuración ──────────────────────────────────────────────────────────────
BASE_DIR   = Path(".")                          # directorio raíz del proyecto
SRC_DIR    = BASE_DIR / "Documentos_prompts_base_docx"
DST_DIR    = BASE_DIR / "Documentos_prompts_base_md"
# ───────────────────────────────────────────────────────────────────────────────

converted  = []
errors     = []

# Recorrer todas las subcarpetas de la fuente
for docx_path in sorted(SRC_DIR.rglob("*.docx")):
    # Ruta relativa respecto a SRC_DIR (e.g. "1.Investigación/archivo.docx")
    rel_path = docx_path.relative_to(SRC_DIR)

    # Destino: misma estructura de subcarpeta, extensión cambiada a .md
    md_rel_path = rel_path.with_suffix(".md")
    md_path     = DST_DIR / md_rel_path

    # Crear la carpeta destino si no existe
    md_path.parent.mkdir(parents=True, exist_ok=True)

    try:
        # 1. mammoth convierte el .docx a HTML conservando estructura básica
        with open(docx_path, "rb") as f:
            result = mammoth.convert_to_html(f)
        html_content = result.value

        # 2. markdownify convierte el HTML a Markdown
        md_content = md(
            html_content,
            heading_style="ATX",   # encabezados con #
            bullets="-",            # listas con -
            strip=["a"],            # eliminar hipervínculos vacíos si los hay
        )

        # 3. Guardar el archivo .md
        md_path.write_text(md_content, encoding="utf-8")

        converted.append(str(md_rel_path))
        print(f"✅  {rel_path}  →  {md_rel_path}")

        # Mostrar advertencias de conversión de mammoth si las hay
        for msg in result.messages:
            print(f"   ⚠️  {msg}")

    except Exception as e:
        errors.append((str(rel_path), str(e)))
        print(f"❌  Error en {rel_path}: {e}")

# ── Resumen ────────────────────────────────────────────────────────────────────
print()
print("═" * 60)
print(f"Conversión completada: {len(converted)} archivo(s) convertido(s).")
if errors:
    print(f"Errores: {len(errors)}")
    for path, err in errors:
        print(f"  - {path}: {err}")
print("═" * 60)
# Out:
# ✅  1.Investigacion\benchmark.docx  →  1.Investigacion\benchmark.md
# ✅  1.Investigacion\discussion-forums.docx  →  1.Investigacion\discussion-forums.md
# ✅  1.Investigacion\search-trend-analysis.docx  →  1.Investigacion\search-trend-analysis.md
# ✅  2.Descubrimiento\a-day-in-the-life.docx  →  2.Descubrimiento\a-day-in-the-life.md
# ✅  2.Descubrimiento\discovery-survey.docx  →  2.Descubrimiento\discovery-survey.md
# ✅  2.Descubrimiento\encuesta-modelo-kano.docx  →  2.Descubrimiento\encuesta-modelo-kano.md
# ✅  2.Descubrimiento\entrevistas-de-empatia.docx  →  2.Descubrimiento\entrevistas-de-empatia.md
# ✅  2.Descubrimiento\expo-quest.docx  →  2.Descubrimiento\expo-quest.md
# ✅  2.Descubrimiento\journey-builder-structure.docx  →  2.Descubrimiento\journey-builder-structure.md
# ✅  2.Descubrimiento\persona-profile.docx  →  2.Descubrimiento\persona-profile.md
# ✅  2.Descubrimiento\problem-solution-fit.docx  →  2.Descubrimiento\problem-solution-fit.md
# ✅  3.Ideacion\business-model-navigator.docx  →  3.Ideacion\business-model-navigator.md
# ✅  3.Ideacion\caressing-the-client.docx  →  3.Ideacion\caressing-the-client.md
# ✅  3.Ideacion\dimensionador-estrategico-de-ideas.docx  →  3.Ideacion\dimensionador-estrategico-de-ideas.md
# ✅  3.Ideacion\how-might-we.docx  →  3.Ideacion\how-might-we.md
# ✅  3.Ideacion\ideacion.docx  →  3.Ideacion\ideacion.md
# ✅  3.Ideacion\referral-builder.docx  →  3.Ideacion\referral-builder.md
# ✅  4.Prototipado\landing-page-ux-analyzer.docx  →  4.Prototipado\landing-page-ux-analyzer.md
# ✅  4.Prototipado\landing-page.docx  →  4.Prototipado\landing-page.md
# ✅  5.Validacion\e-mail-campaign.docx  →  5.Validacion\e-mail-campaign.md
# ✅  5.Validacion\explainer-video.docx  →  5.Validacion\explainer-video.md
# ✅  5.Validacion\feature-stub.docx  →  5.Validacion\feature-stub.md
# ✅  5.Validacion\online-ads.docx  →  5.Validacion\online-ads.md
# ✅  5.Validacion\pop-up-store.docx  →  5.Validacion\pop-up-store.md
#
# ════════════════════════════════════════════════════════════
# Conversión completada: 24 archivo(s) convertido(s).
# ════════════════════════════════════════════════════════════
